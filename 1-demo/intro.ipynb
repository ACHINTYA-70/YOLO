# %% [markdown]
# # Object Detection

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\ACHINTYA\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### this is object detection yolo model -> YOLO("yolo11n.pt")

# %%
model=YOLO("yolo11n.pt") 
res=model("test.jpeg")
res[0].show()
# Out:
# image 1/1 C:\Users\ACHINTYA\OneDrive\Desktop\YOLO\1-demo\test.jpeg: 448x640 6 persons, 1 sports ball, 90.2ms
# Speed: 5.4ms preprocess, 90.2ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
# model=YOLO("yolo11n.pt")
# res=model("vid1.mp4",save=True)

# %%
# model=YOLO("yolo11n.pt")
# res=model("vid.mp4",save=True)

# %% [markdown]
# # Segmentation Detection

# %%
model=YOLO("yolo11n-seg.pt")
res=model("test.jpeg")
res[0].show()
# Out:
# image 1/1 C:\Users\ACHINTYA\OneDrive\Desktop\YOLO\1-demo\test.jpeg: 448x640 6 persons, 1 sports ball, 74.0ms
# Speed: 2.6ms preprocess, 74.0ms inference, 6.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
# model=YOLO("yolo11n-seg.pt")
# res=model("vid1.mp4",save=True)

# %% [markdown]
# # Pose Detection

# %%
model=YOLO("yolo11n-pose.pt")
res=model("test.jpeg")
res[0].show()
# Out:
# ...
#
# image 1/1 C:\Users\ACHINTYA\OneDrive\Desktop\YOLO\1-demo\test.jpeg: 448x640 6 persons, 74.9ms
# Speed: 3.6ms preprocess, 74.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
# model=YOLO("yolo11n-pose.pt")
# res=model("vid1.mp4",save=True)

# %% [markdown]
# # Image Classification

# %%
model=YOLO("yolo11n-cls.pt")
res=model("coffee.png")
res[0].show()
# Out:
# image 1/1 C:\Users\ACHINTYA\OneDrive\Desktop\YOLO\1-demo\coffee.png: 224x224 coffee_mug 0.76, cup 0.11, espresso 0.02, measuring_cup 0.02, coffeepot 0.02, 26.0ms
# Speed: 69.3ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# # OBB detection

# %%
model=YOLO("yolo11n-obb.pt")
res=model("vid1.mp4",save=True)
